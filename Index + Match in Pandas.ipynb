# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir(r"C:\Users\Daniel\Documents\Feature Engineering\KPMG")

# %%
df_1=pd.read_excel("Customer Demographic data.xlsx")
df_2=pd.read_excel("Transactions_clean.xlsx")

# %% [markdown]
# # Index + Match in pandas

# %%
# we are only adding one column (list_price)
df_1_list_price=df_1.merge(df_2[['customer_id','list_price']],how='left',on='customer_id')
df_1_list_price
# Out:
#        customer_id first_name  last_name  gender  \
# 0                1    Laraine  Medendorp       F
# 1                1    Laraine  Medendorp       F
# 2                1    Laraine  Medendorp       F
# 3                1    Laraine  Medendorp       F
# 4                1    Laraine  Medendorp       F
# ...            ...        ...        ...     ...
# 20499         3996    Rosalia   Halgarth  Female
# 20500         3997     Blanch     Nisuis  Female
# 20501         3998     Sarene    Woolley       U
# 20502         3999  Patrizius        NaN    Male
# 20503         4000      Kippy    Oldland    Male
#
#        past_3_years_bike_related_purchases        DOB              job_title  \
# 0                                       93 1953-10-12    Executive Secretary
# 1                                       93 1953-10-12    Executive Secretary
# 2                                       93 1953-10-12    Executive Secretary
# ...

# %%
df_1.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
df_2.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
df_3=pd.read_excel("Customer Addresses_clean.xlsx")
print(df_1.shape)
print(df_3.shape)
# Out:
# (4000, 13)
# (3999, 6)

# %%
#Add all columns of df_3 
df_1.all=df_1.merge(df_3,how='left',on='customer_id')
df_1.all
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 1954-01-20      Recruiting Manager
# ...

# %%
df_1.all.shape
# Out:
# (4000, 18)

# %%
df_1.all.drop('default',axis=1,inplace=True)

# %%
df_1.all.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Health      Mass Customer                  N      Yes
# 1    Financial Services      Mass Customer                  N      Yes
# ...

# %%
df_1.all.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')
